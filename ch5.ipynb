# %%
import common.time_layers as TL
import numpy as np


class SimpleRnnlm:
    def __init__(self, vocab_size: int, wordvec_size: int, hidden_size: int) -> None:
        V, D, H = vocab_size, wordvec_size, hidden_size
        rn = np.random.randn

        embed_W = (rn(V, D) / 100).astype("f")
        rnn_Wx = (rn(D, H)/np.sqrt(D)).astype("f")
        rnn_Wh = (rn(H, H)/np.sqrt(H).astype("f"))
        rnn_b = np.zeros(H).astype("f")
        affine_W = (rn(H, V)/np.sqrt(H)).astype("f")
        affine_b = np.zeros(V).astype("f")

        self.layers = [
            TL.TimeEmbedding(embed_W),
            TL.TimeRNN(rnn_Wx, rnn_Wh, rnn_b, stateful=True),
            TL.TimeAffine(affine_W, affine_b)
        ]

        self.loss_layer = TL.TimeSoftmaxWithLoss()
        self.rnn_layer = self.layers[1]

        self.params, self.grads = [], []
        for layer in self.layers:
            self.params.extend(layer.params)
            self.grads.extend(layer.grads)

    def forward(self, xs, ts):
        for layer in self.layers:
            xs = layer.forward(xs)
        loss = self.loss_layer.forward(xs, ts)
        return loss

    def backward(self, dout=1):
        dout = self.loss_layer.backward(dout)
        for layer in reversed(self.layers):
            dout = layer.backward(dout)
        return dout

    def reset_state(self):
        self.rnn_layer.reset_state()

# %%
import matplotlib.pyplot as plt
import numpy as np
from common.optimizers import SGD
from dataset import ptb


# ハイパーパラメータの設定
batch_size = 10
wordvec_size = 100
hidden_size = 100
time_size = 5  # Truncated BPTTの展開する時間サイズ
lr = 0.1
max_epoch = 100

# 学習データの読み込み（データセットを小さくする）
corpus, word_to_id, id_to_word = ptb.load_data('train')
corpus_size = 1000
corpus = corpus[:corpus_size]
vocab_size = int(max(corpus) + 1)

xs = corpus[:-1]  # 入力
ts = corpus[1:]  # 出力（教師ラベル）
data_size = len(xs)
print('corpus size: %d, vocabulary size: %d' % (corpus_size, vocab_size))

# 学習時に使用する変数
max_iters = data_size // (batch_size * time_size)
time_idx = 0
total_loss = 0
loss_count = 0
ppl_list = []

# モデルの生成
model = SimpleRnnlm(vocab_size, wordvec_size, hidden_size)
optimizer = SGD(lr)

# ミニバッチの各サンプルの読み込み開始位置を計算
jump = (corpus_size - 1) // batch_size
offsets = [i * jump for i in range(batch_size)]

for epoch in range(max_epoch):
    for iter in range(max_iters):
        # ミニバッチの取得
        batch_x = np.empty((batch_size, time_size), dtype='i')
        batch_t = np.empty((batch_size, time_size), dtype='i')
        for t in range(time_size):
            for i, offset in enumerate(offsets):
                batch_x[i, t] = xs[(offset + time_idx) % data_size]
                batch_t[i, t] = ts[(offset + time_idx) % data_size]
            time_idx += 1

        # 勾配を求め、パラメータを更新
        loss = model.forward(batch_x, batch_t)
        model.backward()
        optimizer.update(model.params, model.grads)
        total_loss += loss
        loss_count += 1

    # エポックごとにパープレキシティの評価
    ppl = np.exp(total_loss / loss_count)
    print('| epoch %d | perplexity %.2f'
          % (epoch+1, ppl))
    ppl_list.append(float(ppl))
    total_loss, loss_count = 0, 0

# グラフの描画
x = np.arange(len(ppl_list))
plt.plot(x, ppl_list, label='train')
plt.xlabel('epochs')
plt.ylabel('perplexity')
plt.show()
# Out:
# corpus size: 1000, vocabulary size: 418
# | epoch 1 | perplexity 430.42
# | epoch 2 | perplexity 385.84
# | epoch 3 | perplexity 296.98
# | epoch 4 | perplexity 239.98
# | epoch 5 | perplexity 216.85
# | epoch 6 | perplexity 208.60
# | epoch 7 | perplexity 202.79
# | epoch 8 | perplexity 198.88
# | epoch 9 | perplexity 193.40
# | epoch 10 | perplexity 194.64
# | epoch 11 | perplexity 189.67
# | epoch 12 | perplexity 193.09
# | epoch 13 | perplexity 191.13
# | epoch 14 | perplexity 190.90
# | epoch 15 | perplexity 191.25
# | epoch 16 | perplexity 188.23
# | epoch 17 | perplexity 186.07
# | epoch 18 | perplexity 183.22
# | epoch 19 | perplexity 184.61
# | epoch 20 | perplexity 186.53
# | epoch 21 | perplexity 184.48
# | epoch 22 | perplexity 180.95
# | epoch 23 | perplexity 178.65
# | epoch 24 | perplexity 180.84
# | epoch 25 | perplexity 179.61
# | epoch 26 | perplexity 180.85
# | epoch 27 | perplexity 176.37
# | epoch 28 | perplexity 177.00
# | epoch 29 | perplexity 175.24
# | epoch 30 | perplexity 171.31
# | epoch 31 | perplexity 174.36
# | epoch 32 | perplexity 170.76
# | epoch 33 | perplexity 172.50
# | epoch 34 | perplexity 169.83
# | epoch 35 | perplexity 171.79
# | epoch 36 | perplexity 167.00
# | epoch 37 | perplexity 165.21
# | epoch 38 | perplexity 164.32
# | epoch 39 | perplexity 160.57
# | epoch 40 | perplexity 159.02
# | epoch 41 | perplexity 162.08
# | epoch 42 | perplexity 156.31
# | epoch 43 | perplexity 152.26
# | epoch 44 | perplexity 151.53
# | epoch 45 | perplexity 150.25
# | epoch 46 | perplexity 150.45
# | epoch 47 | perplexity 145.74
# | epoch 48 | perplexity 140.80
# | epoch 49 | perplexity 139.21
# | epoch 50 | perplexity 137.44
# | epoch 51 | perplexity 134.48
# | epoch 52 | perplexity 132.62
# | epoch 53 | perplexity 128.92
# | epoch 54 | perplexity 129.30
# | epoch 55 | perplexity 125.58
# | epoch 56 | perplexity 120.14
# | epoch 57 | perplexity 118.41
# | epoch 58 | perplexity 114.50
# | epoch 59 | perplexity 112.06
# | epoch 60 | perplexity 108.30
# | epoch 61 | perplexity 107.70
# | epoch 62 | perplexity 104.54
# | epoch 63 | perplexity 97.80
# | epoch 64 | perplexity 97.00
# | epoch 65 | perplexity 94.92
# | epoch 66 | perplexity 91.92
# | epoch 67 | perplexity 89.51
# | epoch 68 | perplexity 82.77
# | epoch 69 | perplexity 81.55
# | epoch 70 | perplexity 79.29
# | epoch 71 | perplexity 77.12
# | epoch 72 | perplexity 73.67
# | epoch 73 | perplexity 71.00
# | epoch 74 | perplexity 69.10
# | epoch 75 | perplexity 67.76
# | epoch 76 | perplexity 63.23
# | epoch 77 | perplexity 61.74
# | epoch 78 | perplexity 59.30
# | epoch 79 | perplexity 56.89
# | epoch 80 | perplexity 54.35
# | epoch 81 | perplexity 52.73
# | epoch 82 | perplexity 52.15
# | epoch 83 | perplexity 48.46
# | epoch 84 | perplexity 46.90
# | epoch 85 | perplexity 45.62
# | epoch 86 | perplexity 43.68
# | epoch 87 | perplexity 42.01
# | epoch 88 | perplexity 39.65
# | epoch 89 | perplexity 37.49
# | epoch 90 | perplexity 36.79
# | epoch 91 | perplexity 35.75
# | epoch 92 | perplexity 33.95
# | epoch 93 | perplexity 32.95
# | epoch 94 | perplexity 31.33
# | epoch 95 | perplexity 29.86
# | epoch 96 | perplexity 28.45
# | epoch 97 | perplexity 27.36
# | epoch 98 | perplexity 26.06
# | epoch 99 | perplexity 24.96
# | epoch 100 | perplexity 23.83
