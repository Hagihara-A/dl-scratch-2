# %%
import common.time_layers as TL
import numpy as np


class SimpleRnnlm:
    def __init__(self, vocab_size: int, wordvec_size: int, hidden_size: int) -> None:
        V, D, H = vocab_size, wordvec_size, hidden_size
        rn = np.random.randn

        embed_W = (rn(V, D) / 100).astype("f")
        rnn_Wx = (rn(D, H)/np.sqrt(D)).astype("f")
        rnn_Wh = (rn(H, H)/np.sqrt(H).astype("f"))
        rnn_b = np.zeros(H).astype("f")
        affine_W = (rn(H, V)/np.sqrt(H)).astype("f")
        affine_b = np.zeros(V).astype("f")

        self.layers = [
            TL.TimeEmbedding(embed_W),
            TL.TimeRNN(rnn_Wx, rnn_Wh, rnn_b, stateful=True),
            TL.TimeAffine(affine_W, affine_b)
        ]

        self.loss_layer = TL.TimeSoftmaxWithLoss()
        self.rnn_layer = self.layers[1]

        self.params, self.grads = [], []
        for layer in self.layers:
            self.params += layer.params
            self.grads += layer.grads

    def forward(self, xs, ts):
        for layer in self.layers:
            xs = layer.forward(xs)
        loss = self.loss_layer.forward(xs, ts)
        return loss

    def backward(self, dout=1):
        dout = self.loss_layer.backward(dout)
        for layer in reversed(self.layers):
            dout = layer.backward(dout)
        return dout

    def reset_state(self):
        self.rnn_layer.reset_state()

# %%
import matplotlib.pyplot as plt
import numpy as np
from common.optimizers import SGD
from dataset import ptb


# ハイパーパラメータの設定
batch_size = 10
wordvec_size = 100
hidden_size = 100
time_size = 5  # Truncated BPTTの展開する時間サイズ
lr = 0.1
max_epoch = 100

# 学習データの読み込み（データセットを小さくする）
corpus, word_to_id, id_to_word = ptb.load_data('train')
corpus_size = 1000
corpus = corpus[:corpus_size]
vocab_size = int(max(corpus) + 1)

xs = corpus[:-1]  # 入力
ts = corpus[1:]  # 出力（教師ラベル）
data_size = len(xs)
print('corpus size: %d, vocabulary size: %d' % (corpus_size, vocab_size))

# 学習時に使用する変数
max_iters = data_size // (batch_size * time_size)
time_idx = 0
total_loss = 0
loss_count = 0
ppl_list = []

# モデルの生成
model = SimpleRnnlm(vocab_size, wordvec_size, hidden_size)
optimizer = SGD(lr)

# ミニバッチの各サンプルの読み込み開始位置を計算
jump = (corpus_size - 1) // batch_size
offsets = [i * jump for i in range(batch_size)]

for epoch in range(max_epoch):
    for iter in range(max_iters):
        # ミニバッチの取得
        batch_x = np.empty((batch_size, time_size), dtype='i')
        batch_t = np.empty((batch_size, time_size), dtype='i')
        for t in range(time_size):
            for i, offset in enumerate(offsets):
                batch_x[i, t] = xs[(offset + time_idx) % data_size]
                batch_t[i, t] = ts[(offset + time_idx) % data_size]
            time_idx += 1

        # 勾配を求め、パラメータを更新
        loss = model.forward(batch_x, batch_t)
        model.backward()
        optimizer.update(model.params, model.grads)
        total_loss += loss
        loss_count += 1

    # エポックごとにパープレキシティの評価
    ppl = np.exp(total_loss / loss_count)
    print('| epoch %d | perplexity %.2f'
          % (epoch+1, ppl))
    ppl_list.append(float(ppl))
    total_loss, loss_count = 0, 0

# グラフの描画
x = np.arange(len(ppl_list))
plt.plot(x, ppl_list, label='train')
plt.xlabel('epochs')
plt.ylabel('perplexity')
plt.show()
# Out:
# corpus size: 1000, vocabulary size: 418
# | epoch 1 | perplexity 411.75
# | epoch 2 | perplexity 387.33
# | epoch 3 | perplexity 334.14
# | epoch 4 | perplexity 250.37
# | epoch 5 | perplexity 221.26
# | epoch 6 | perplexity 211.40
# | epoch 7 | perplexity 204.54
# | epoch 8 | perplexity 200.62
# | epoch 9 | perplexity 194.40
# | epoch 10 | perplexity 195.02
# | epoch 11 | perplexity 190.30
# | epoch 12 | perplexity 192.79
# | epoch 13 | perplexity 191.49
# | epoch 14 | perplexity 191.60
# | epoch 15 | perplexity 191.08
# | epoch 16 | perplexity 187.50
# | epoch 17 | perplexity 185.33
# | epoch 18 | perplexity 182.11
# | epoch 19 | perplexity 183.94
# | epoch 20 | perplexity 185.86
# | epoch 21 | perplexity 184.12
# | epoch 22 | perplexity 180.16
# | epoch 23 | perplexity 177.70
# | epoch 24 | perplexity 179.71
# | epoch 25 | perplexity 178.24
# | epoch 26 | perplexity 178.87
# | epoch 27 | perplexity 174.06
# | epoch 28 | perplexity 174.53
# | epoch 29 | perplexity 172.53
# | epoch 30 | perplexity 168.02
# | epoch 31 | perplexity 170.75
# | epoch 32 | perplexity 167.35
# | epoch 33 | perplexity 168.53
# | epoch 34 | perplexity 165.72
# | epoch 35 | perplexity 166.51
# | epoch 36 | perplexity 161.66
# | epoch 37 | perplexity 159.26
# | epoch 38 | perplexity 157.69
# | epoch 39 | perplexity 153.70
# | epoch 40 | perplexity 151.66
# | epoch 41 | perplexity 153.68
# | epoch 42 | perplexity 148.60
# | epoch 43 | perplexity 143.95
# | epoch 44 | perplexity 141.46
# | epoch 45 | perplexity 139.61
# | epoch 46 | perplexity 139.75
# | epoch 47 | perplexity 134.21
# | epoch 48 | perplexity 129.66
# | epoch 49 | perplexity 128.03
# | epoch 50 | perplexity 125.39
# | epoch 51 | perplexity 122.64
# | epoch 52 | perplexity 119.98
# | epoch 53 | perplexity 115.71
# | epoch 54 | perplexity 114.01
# | epoch 55 | perplexity 111.13
# | epoch 56 | perplexity 105.94
# | epoch 57 | perplexity 103.77
# | epoch 58 | perplexity 99.66
# | epoch 59 | perplexity 96.72
# | epoch 60 | perplexity 93.80
# | epoch 61 | perplexity 91.98
# | epoch 62 | perplexity 89.11
# | epoch 63 | perplexity 83.13
# | epoch 64 | perplexity 80.64
# | epoch 65 | perplexity 79.34
# | epoch 66 | perplexity 76.17
# | epoch 67 | perplexity 74.12
# | epoch 68 | perplexity 68.74
# | epoch 69 | perplexity 67.09
# | epoch 70 | perplexity 65.10
# | epoch 71 | perplexity 63.14
# | epoch 72 | perplexity 59.78
# | epoch 73 | perplexity 57.61
# | epoch 74 | perplexity 54.80
# | epoch 75 | perplexity 53.45
# | epoch 76 | perplexity 49.67
# | epoch 77 | perplexity 48.27
# | epoch 78 | perplexity 46.01
# | epoch 79 | perplexity 43.56
# | epoch 80 | perplexity 41.81
# | epoch 81 | perplexity 40.12
# | epoch 82 | perplexity 39.25
# | epoch 83 | perplexity 36.15
# | epoch 84 | perplexity 34.77
# | epoch 85 | perplexity 33.33
# | epoch 86 | perplexity 31.71
# | epoch 87 | perplexity 30.84
# | epoch 88 | perplexity 28.86
# | epoch 89 | perplexity 27.33
# | epoch 90 | perplexity 26.30
# | epoch 91 | perplexity 25.68
# | epoch 92 | perplexity 24.47
# | epoch 93 | perplexity 23.29
# | epoch 94 | perplexity 22.36
# | epoch 95 | perplexity 21.00
# | epoch 96 | perplexity 20.31
# | epoch 97 | perplexity 19.36
# | epoch 98 | perplexity 18.45
# | epoch 99 | perplexity 17.84
# | epoch 100 | perplexity 16.87
